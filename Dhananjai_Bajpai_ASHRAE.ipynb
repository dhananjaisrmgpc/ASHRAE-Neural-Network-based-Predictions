# %%
#  Team - EE258_F19_DJAP

# %%
# Best Performing Model

# %%
# ANIKET PHATAK
# DHANANJAY BAJPAI

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)


import os
for dirname, _, filenames in os.walk('/Users/x/Downloads/NN/'):
    for filename in filenames:
        print(os.path.join(dirname, filename))



from keras.models import Model, load_model
from keras.layers import Input, Dropout, Dense, Embedding, SpatialDropout1D, concatenate, BatchNormalization, Flatten
from keras.preprocessing.sequence import pad_sequences
from keras.preprocessing import text, sequence
from keras.callbacks import Callback
from keras import backend as K
from keras.models import Model
from keras.losses import mean_squared_error as mse_loss

from keras import optimizers
from keras.optimizers import RMSprop, Adam
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
# Out:
# /Users/x/Downloads/NN/model_3.hdf5
# /Users/x/Downloads/NN/weather_test.csv
# /Users/x/Downloads/NN/weather_train.csv
# /Users/x/Downloads/NN/my_submission.csv
# /Users/x/Downloads/NN/model_2.hdf5
# /Users/x/Downloads/NN/test.csv
# /Users/x/Downloads/NN/Best performing model_Neural Network.ipynb
# /Users/x/Downloads/NN/train.csv
# /Users/x/Downloads/NN/building_metadata.csv
# /Users/x/Downloads/NN/model_1.hdf5
# /Users/x/Downloads/NN/model_0.hdf5
# /Users/x/Downloads/NN/sample_submission.csv
# /Users/x/Downloads/NN/.ipynb_checkpoints/Best performing model_Neural Network-checkpoint.ipynb
# Using TensorFlow backend.
# /Applications/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /Applications/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /Applications/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /Applications/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /Applications/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /Applications/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
def average_imputation(df, column_name):
    imputation = df.groupby(['timestamp'])[column_name].mean()
    
    df.loc[df[column_name].isnull(), column_name] = df[df[column_name].isnull()][[column_name]].apply(lambda x: imputation[df['timestamp'][x.index]].values)
    del imputation
    return df

# %% [markdown]
# # COMBINE Building and weather files

# %%
building_df = pd.read_csv("/Users/x/Downloads/NN/building_metadata.csv")
weather_train = pd.read_csv("/Users/x/Downloads/NN/weather_train.csv")
train = pd.read_csv("/Users/x/Downloads/NN/train.csv")

train = train.merge(building_df, left_on = "building_id", right_on = "building_id", how = "left")
train = train.merge(weather_train, left_on = ["site_id", "timestamp"], right_on = ["site_id", "timestamp"])
del weather_train

train.loc[(train['meter']==0) & (train['site_id']==0) & (train['timestamp']<'2016-05-21 00:00:00'), 'drop'] = True
train = train[train['drop']!=True]

train["timestamp"] = pd.to_datetime(train["timestamp"])
train["hour"] = train["timestamp"].dt.hour
train["weekday"] = train["timestamp"].dt.weekday

train = average_imputation(train, 'wind_speed')

beaufort = [(0, 0, 0.3), (1, 0.3, 1.6), (2, 1.6, 3.4), (3, 3.4, 5.5), (4, 5.5, 8), (5, 8, 10.8), (6, 10.8, 13.9), 
          (7, 13.9, 17.2), (8, 17.2, 20.8), (9, 20.8, 24.5), (10, 24.5, 28.5), (11, 28.5, 33), (12, 33, 200)]

for item in beaufort:
    train.loc[(train['wind_speed']>=item[1]) & (train['wind_speed']<item[2]), 'beaufort_scale'] = item[0]

del train["timestamp"]

# %%
# Handling categorical and numerical values

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
train["primary_use"] = le.fit_transform(train["primary_use"])

categoricals = ["site_id", "building_id", "primary_use", "hour", "weekday",  "meter"]

drop_cols = ["sea_level_pressure", "wind_speed", "wind_direction"]

numericals = ["square_feet", "year_built", "air_temperature", "cloud_coverage",
              "dew_temperature", "precip_depth_1_hr", "floor_count", 'beaufort_scale']

feat_cols = categoricals + numericals

# %%
target = np.log1p(train["meter_reading"])

del train["meter_reading"] 

train = train.drop(drop_cols, axis = 1)

# %%
# Reducing memory footprint

# %%
#Based on this great kernel https://www.kaggle.com/arjanso/reducing-dataframe-memory-size-by-65
def reduce_mem_usage(df):
    start_mem_usg = df.memory_usage().sum() / 1024**2 
    print("Memory usage of properties dataframe is :",start_mem_usg," MB")
    NAlist = [] # Keeps track of columns that have missing values filled in. 
    for col in df.columns:
        if df[col].dtype != object:  # Exclude strings            
            # Print current column type
            print("******************************")
            print("Column: ",col)
            print("dtype before: ",df[col].dtype)            
            # make variables for Int, max and min
            IsInt = False
            mx = df[col].max()
            mn = df[col].min()
            print("min for this col: ",mn)
            print("max for this col: ",mx)
            # Integer does not support NA, therefore, NA needs to be filled
            if not np.isfinite(df[col]).all(): 
                NAlist.append(col)
                df[col].fillna(mn-1,inplace=True)  
                   
            # test if column can be converted to an integer
            asint = df[col].fillna(0).astype(np.int64)
            result = (df[col] - asint)
            result = result.sum()
            if result > -0.01 and result < 0.01:
                IsInt = True            
            # Make Integer/unsigned Integer datatypes
            if IsInt:
                if mn >= 0:
                    if mx < 255:
                        df[col] = df[col].astype(np.uint8)
                    elif mx < 65535:
                        df[col] = df[col].astype(np.uint16)
                    elif mx < 4294967295:
                        df[col] = df[col].astype(np.uint32)
                    else:
                        df[col] = df[col].astype(np.uint64)
                else:
                    if mn > np.iinfo(np.int8).min and mx < np.iinfo(np.int8).max:
                        df[col] = df[col].astype(np.int8)
                    elif mn > np.iinfo(np.int16).min and mx < np.iinfo(np.int16).max:
                        df[col] = df[col].astype(np.int16)
                    elif mn > np.iinfo(np.int32).min and mx < np.iinfo(np.int32).max:
                        df[col] = df[col].astype(np.int32)
                    elif mn > np.iinfo(np.int64).min and mx < np.iinfo(np.int64).max:
                        df[col] = df[col].astype(np.int64)    
            # Make float datatypes 32 bit
            else:
                df[col] = df[col].astype(np.float32)
            
            # Print new column type
            print("dtype after: ",df[col].dtype)
            print("******************************")
    # Print final result
    print("___MEMORY USAGE AFTER COMPLETION:___")
    mem_usg = df.memory_usage().sum() / 1024**2 
    print("Memory usage is: ",mem_usg," MB")
    print("This is ",100*mem_usg/start_mem_usg,"% of the initial size")
    return df, NAlist

# %%
train, NAlist = reduce_mem_usage(train)
# Out:
# Memory usage of properties dataframe is : 3054.1900634765625  MB
# ******************************
# Column:  building_id
# dtype before:  int64
# min for this col:  0
# max for this col:  1448
# dtype after:  uint16
# ******************************
# ******************************
# Column:  meter
# dtype before:  int64
# min for this col:  0
# max for this col:  3
# dtype after:  uint8
# ******************************
# ******************************
# Column:  site_id
# dtype before:  int64
# min for this col:  0
# max for this col:  15
# dtype after:  uint8
# ******************************
# ******************************
# Column:  primary_use
# dtype before:  int64
# min for this col:  0
# max for this col:  15
# dtype after:  uint8
# ******************************
# ******************************
# Column:  square_feet
# dtype before:  int64
# min for this col:  283
# max for this col:  875000
# dtype after:  uint32
# ******************************
# ******************************
# Column:  year_built
# dtype before:  float64
# min for this col:  1900.0
# max for this col:  2017.0
# dtype after:  uint16
# ******************************
# ******************************
# Column:  floor_count
# dtype before:  float64
# min for this col:  1.0
# max for this col:  26.0
# dtype after:  uint8
# ******************************
# ******************************
# Column:  air_temperature
# dtype before:  float64
# min for this col:  -28.9
# max for this col:  47.2
# dtype after:  float32
# ******************************
# ******************************
# Column:  cloud_coverage
# dtype before:  float64
# min for this col:  0.0
# max for this col:  9.0
# dtype after:  uint8
# ******************************
# ******************************
# Column:  dew_temperature
# dtype before:  float64
# min for this col:  -35.0
# max for this col:  26.1
# dtype after:  float32
# ******************************
# ******************************
# Column:  precip_depth_1_hr
# dtype before:  float64
# min for this col:  -1.0
# max for this col:  343.0
# dtype after:  int16
# ******************************
# ******************************
# Column:  hour
# dtype before:  int64
# min for this col:  0
# max for this col:  23
# dtype after:  uint8
# ******************************
# ******************************
# Column:  weekday
# dtype before:  int64
# min for this col:  0
# max for this col:  6
# dtype after:  uint8
# ******************************
# ******************************
# Column:  beaufort_scale
# dtype before:  float64
# min for this col:  0.0
# max for this col:  8.0
# dtype after:  uint8
# ******************************
# ___MEMORY USAGE AFTER COMPLETION:___
# Memory usage is:  1432.156114578247  MB
# This is  46.89151902183959 % of the initial size

# %%
# Setting up the Neural Network Model //

# %%
def model(dense_dim_1=128, dense_dim_2=64, dense_dim_3=64, dense_dim_4=32, 
dropout1=0.2, dropout2=0.1, dropout3=0.1, dropout4=0.1, lr=0.001):

    #Inputs
    site_id = Input(shape=[1], name="site_id")
    building_id = Input(shape=[1], name="building_id")
    meter = Input(shape=[1], name="meter")
    primary_use = Input(shape=[1], name="primary_use")
    square_feet = Input(shape=[1], name="square_feet")
    year_built = Input(shape=[1], name="year_built")
    air_temperature = Input(shape=[1], name="air_temperature")
    cloud_coverage = Input(shape=[1], name="cloud_coverage")
    dew_temperature = Input(shape=[1], name="dew_temperature")
    hour = Input(shape=[1], name="hour")
    precip = Input(shape=[1], name="precip_depth_1_hr")
    weekday = Input(shape=[1], name="weekday")
    beaufort_scale = Input(shape=[1], name="beaufort_scale")
   
    #Embeddings layers
    emb_site_id = Embedding(16, 2)(site_id)
    emb_building_id = Embedding(1449, 6)(building_id)
    emb_meter = Embedding(4, 2)(meter)
    emb_primary_use = Embedding(16, 2)(primary_use)
    emb_hour = Embedding(24, 3)(hour)
    emb_weekday = Embedding(7, 2)(weekday)

    concat_emb = concatenate([
           Flatten() (emb_site_id)
         , Flatten() (emb_building_id)
         , Flatten() (emb_meter)
         , Flatten() (emb_primary_use)
         , Flatten() (emb_hour)
         , Flatten() (emb_weekday)
    ])
    
    categ = Dropout(dropout1)(Dense(dense_dim_1,activation='relu') (concat_emb))
    categ = BatchNormalization()(categ)
    categ = Dropout(dropout2)(Dense(dense_dim_2,activation='relu') (categ))
    
    #main layer
    main_l = concatenate([
          categ
        , square_feet
        , year_built
        , air_temperature
        , cloud_coverage
        , dew_temperature
        , precip
        , beaufort_scale
    ])
    
    main_l = Dropout(dropout3)(Dense(dense_dim_3,activation='relu') (main_l))
    main_l = BatchNormalization()(main_l)
    main_l = Dropout(dropout4)(Dense(dense_dim_4,activation='relu') (main_l))
    
    #output
    output = Dense(1) (main_l)

    model = Model([ site_id,
                    building_id, 
                    meter, 
                    primary_use, 
                    square_feet, 
                    year_built, 
                    air_temperature,
                    cloud_coverage,
                    dew_temperature, 
                    hour,
                    weekday, 
                    precip,
                    beaufort_scale], output)

    model.compile(optimizer = Adam(lr=lr),
                  loss= mse_loss,
                  metrics=[root_mean_squared_error])
    return model

def root_mean_squared_error(y_true, y_pred):
    return K.sqrt(K.mean(K.square(y_pred - y_true), axis=0))

# %%
def get_keras_data(df, num_cols, cat_cols):
    cols = num_cols + cat_cols
    X = {col: np.array(df[col]) for col in cols}
    return X

def train_model(keras_model, X_t, y_train, batch_size, epochs, X_v, y_valid, fold, patience=3):
    early_stopping = EarlyStopping(patience=patience, verbose=1)
    model_checkpoint = ModelCheckpoint("model_" + str(fold) + ".hdf5",
                                       save_best_only=True, verbose=1, monitor='val_root_mean_squared_error', mode='min')

    hist = keras_model.fit(X_t, y_train, batch_size=batch_size, epochs=epochs,
                            validation_data=(X_v, y_valid), verbose=1,
                            callbacks=[early_stopping, model_checkpoint])

    keras_model = load_model("model_" + str(fold) + ".hdf5", custom_objects={'root_mean_squared_error': root_mean_squared_error})
    
    return keras_model

# %%
#4 folds

# %%
from sklearn.model_selection import KFold, StratifiedKFold

oof = np.zeros(len(train))
batch_size = 1024
epochs = 25
models = []

folds = 4
seed = 666

kf = StratifiedKFold(n_splits=folds, shuffle=True, random_state=seed)

for fold_n, (train_index, valid_index) in enumerate(kf.split(train, train['building_id'])):
    print('Fold:', fold_n)
    X_train, X_valid = train.iloc[train_index], train.iloc[valid_index]
    y_train, y_valid = target.iloc[train_index], target.iloc[valid_index]
    X_t = get_keras_data(X_train, numericals, categoricals)
    X_v = get_keras_data(X_valid, numericals, categoricals)
    
    keras_model = model(dense_dim_1=64, dense_dim_2=32, dense_dim_3=32, dense_dim_4=16, 
                        dropout1=0.2, dropout2=0.1, dropout3=0.1, dropout4=0.1, lr=0.001)
    mod = train_model(keras_model, X_t, y_train, batch_size, epochs, X_v, y_valid, fold_n, patience=3)
    models.append(mod)
    print('*'* 50)
# Out:
# Fold: 0
# WARNING:tensorflow:From /Applications/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /Applications/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 14832268 samples, validate on 4944777 samples
# Epoch 1/25
# 14832268/14832268 [==============================] - 122s 8us/step - loss: 1.8947 - root_mean_squared_error: 1.3547 - val_loss: 1.4547 - val_root_mean_squared_error: 1.1908
#
# Epoch 00001: val_root_mean_squared_error improved from inf to 1.19082, saving model to model_0.hdf5
# Epoch 2/25
# 14832268/14832268 [==============================] - 123s 8us/step - loss: 1.5547 - root_mean_squared_error: 1.2456 - val_loss: 1.3964 - val_root_mean_squared_error: 1.1666
#
# Epoch 00002: val_root_mean_squared_error improved from 1.19082 to 1.16659, saving model to model_0.hdf5
# Epoch 3/25
# 14832268/14832268 [==============================] - 122s 8us/step - loss: 1.4007 - root_mean_squared_error: 1.1820 - val_loss: 1.2102 - val_root_mean_squared_error: 1.0832
#
# Epoch 00003: val_root_mean_squared_error improved from 1.16659 to 1.08319, saving model to model_0.hdf5
# Epoch 4/25
# 14832268/14832268 [==============================] - 122s 8us/step - loss: 1.2760 - root_mean_squared_error: 1.1281 - val_loss: 1.0981 - val_root_mean_squared_error: 1.0296
#
# Epoch 00004: val_root_mean_squared_error improved from 1.08319 to 1.02960, saving model to model_0.hdf5
# Epoch 5/25
# 14832268/14832268 [==============================] - 122s 8us/step - loss: 1.2134 - root_mean_squared_error: 1.1000 - val_loss: 1.0206 - val_root_mean_squared_error: 0.9904
#
# Epoch 00005: val_root_mean_squared_error improved from 1.02960 to 0.99038, saving model to model_0.hdf5
# Epoch 6/25
# 14832268/14832268 [==============================] - 123s 8us/step - loss: 1.1725 - root_mean_squared_error: 1.0813 - val_loss: 1.0050 - val_root_mean_squared_error: 0.9809
#
# Epoch 00006: val_root_mean_squared_error improved from 0.99038 to 0.98087, saving model to model_0.hdf5
# Epoch 7/25
# 14832268/14832268 [==============================] - 123s 8us/step - loss: 1.1495 - root_mean_squared_error: 1.0705 - val_loss: 1.0097 - val_root_mean_squared_error: 0.9870
#
# Epoch 00007: val_root_mean_squared_error did not improve from 0.98087
# Epoch 8/25
# 14832268/14832268 [==============================] - 123s 8us/step - loss: 1.1345 - root_mean_squared_error: 1.0635 - val_loss: 0.9779 - val_root_mean_squared_error: 0.9688
#
# Epoch 00008: val_root_mean_squared_error improved from 0.98087 to 0.96879, saving model to model_0.hdf5
# Epoch 9/25
# 14832268/14832268 [==============================] - 123s 8us/step - loss: 1.1237 - root_mean_squared_error: 1.0584 - val_loss: 1.0413 - val_root_mean_squared_error: 1.0002
#
# Epoch 00009: val_root_mean_squared_error did not improve from 0.96879
# Epoch 10/25
# 14832268/14832268 [==============================] - 123s 8us/step - loss: 1.1141 - root_mean_squared_error: 1.0539 - val_loss: 1.0201 - val_root_mean_squared_error: 0.9879
#
# Epoch 00010: val_root_mean_squared_error did not improve from 0.96879
# Epoch 11/25
# 14832268/14832268 [==============================] - 123s 8us/step - loss: 1.1047 - root_mean_squared_error: 1.0495 - val_loss: 0.9996 - val_root_mean_squared_error: 0.9776
#
# Epoch 00011: val_root_mean_squared_error did not improve from 0.96879
# Epoch 00011: early stopping
# **************************************************
# Fold: 1
# Train on 14832479 samples, validate on 4944566 samples
# Epoch 1/25
# 14832479/14832479 [==============================] - 124s 8us/step - loss: 1.7949 - root_mean_squared_error: 1.3229 - val_loss: 1.4382 - val_root_mean_squared_error: 1.1838
#
# Epoch 00001: val_root_mean_squared_error improved from inf to 1.18383, saving model to model_1.hdf5
# Epoch 2/25
# 14832479/14832479 [==============================] - 122s 8us/step - loss: 1.5519 - root_mean_squared_error: 1.2445 - val_loss: 1.4272 - val_root_mean_squared_error: 1.1778
#
# Epoch 00002: val_root_mean_squared_error improved from 1.18383 to 1.17776, saving model to model_1.hdf5
# Epoch 3/25
# 14832479/14832479 [==============================] - 124s 8us/step - loss: 1.4662 - root_mean_squared_error: 1.2091 - val_loss: 1.0938 - val_root_mean_squared_error: 1.0278
#
# Epoch 00003: val_root_mean_squared_error improved from 1.17776 to 1.02782, saving model to model_1.hdf5
# Epoch 4/25
# 14832479/14832479 [==============================] - 124s 8us/step - loss: 1.2538 - root_mean_squared_error: 1.1182 - val_loss: 1.0177 - val_root_mean_squared_error: 0.9889
#
# Epoch 00004: val_root_mean_squared_error improved from 1.02782 to 0.98886, saving model to model_1.hdf5
# Epoch 5/25
# 14832479/14832479 [==============================] - 124s 8us/step - loss: 1.1868 - root_mean_squared_error: 1.0879 - val_loss: 1.0089 - val_root_mean_squared_error: 0.9855
#
# Epoch 00005: val_root_mean_squared_error improved from 0.98886 to 0.98547, saving model to model_1.hdf5
# Epoch 6/25
# 14832479/14832479 [==============================] - 124s 8us/step - loss: 1.1551 - root_mean_squared_error: 1.0732 - val_loss: 1.0016 - val_root_mean_squared_error: 0.9818
#
# Epoch 00006: val_root_mean_squared_error improved from 0.98547 to 0.98181, saving model to model_1.hdf5
# Epoch 7/25
# 14832479/14832479 [==============================] - 123s 8us/step - loss: 1.1367 - root_mean_squared_error: 1.0646 - val_loss: 1.0496 - val_root_mean_squared_error: 1.0081
#
# Epoch 00007: val_root_mean_squared_error did not improve from 0.98181
# Epoch 8/25
# 14832479/14832479 [==============================] - 124s 8us/step - loss: 1.1254 - root_mean_squared_error: 1.0593 - val_loss: 0.9816 - val_root_mean_squared_error: 0.9699
#
# Epoch 00008: val_root_mean_squared_error improved from 0.98181 to 0.96990, saving model to model_1.hdf5
# Epoch 9/25
# 14832479/14832479 [==============================] - 124s 8us/step - loss: 1.1172 - root_mean_squared_error: 1.0554 - val_loss: 0.9597 - val_root_mean_squared_error: 0.9582
#
# Epoch 00009: val_root_mean_squared_error improved from 0.96990 to 0.95816, saving model to model_1.hdf5
# Epoch 10/25
# 14832479/14832479 [==============================] - 124s 8us/step - loss: 1.1119 - root_mean_squared_error: 1.0528 - val_loss: 0.9895 - val_root_mean_squared_error: 0.9744
#
# Epoch 00010: val_root_mean_squared_error did not improve from 0.95816
# Epoch 11/25
# 14832479/14832479 [==============================] - 124s 8us/step - loss: 1.1065 - root_mean_squared_error: 1.0503 - val_loss: 0.9703 - val_root_mean_squared_error: 0.9635
#
# Epoch 00011: val_root_mean_squared_error did not improve from 0.95816
# Epoch 12/25
# 14832479/14832479 [==============================] - 124s 8us/step - loss: 1.1011 - root_mean_squared_error: 1.0477 - val_loss: 0.9757 - val_root_mean_squared_error: 0.9674
#
# Epoch 00012: val_root_mean_squared_error did not improve from 0.95816
# Epoch 00012: early stopping
# **************************************************
# Fold: 2
# Train on 14832969 samples, validate on 4944076 samples
# Epoch 1/25
# 14832969/14832969 [==============================] - 127s 9us/step - loss: 1.9283 - root_mean_squared_error: 1.3605 - val_loss: 1.4592 - val_root_mean_squared_error: 1.1929
#
# Epoch 00001: val_root_mean_squared_error improved from inf to 1.19288, saving model to model_2.hdf5
# Epoch 2/25
# 14832969/14832969 [==============================] - 128s 9us/step - loss: 1.5767 - root_mean_squared_error: 1.2544 - val_loss: 1.4425 - val_root_mean_squared_error: 1.1847
#
# Epoch 00002: val_root_mean_squared_error improved from 1.19288 to 1.18471, saving model to model_2.hdf5
# Epoch 3/25
# 14832969/14832969 [==============================] - 128s 9us/step - loss: 1.5431 - root_mean_squared_error: 1.2410 - val_loss: 1.3419 - val_root_mean_squared_error: 1.1425
#
# Epoch 00003: val_root_mean_squared_error improved from 1.18471 to 1.14251, saving model to model_2.hdf5
# Epoch 4/25
# 14832969/14832969 [==============================] - 129s 9us/step - loss: 1.3480 - root_mean_squared_error: 1.1594 - val_loss: 1.0786 - val_root_mean_squared_error: 1.0181
#
# Epoch 00004: val_root_mean_squared_error improved from 1.14251 to 1.01808, saving model to model_2.hdf5
# Epoch 5/25
# 14832969/14832969 [==============================] - 129s 9us/step - loss: 1.2198 - root_mean_squared_error: 1.1030 - val_loss: 1.0182 - val_root_mean_squared_error: 0.9889
#
# Epoch 00005: val_root_mean_squared_error improved from 1.01808 to 0.98895, saving model to model_2.hdf5
# Epoch 6/25
# 14832969/14832969 [==============================] - 129s 9us/step - loss: 1.1873 - root_mean_squared_error: 1.0881 - val_loss: 1.0461 - val_root_mean_squared_error: 1.0033
#
# Epoch 00006: val_root_mean_squared_error did not improve from 0.98895
# Epoch 7/25
# 14832969/14832969 [==============================] - 129s 9us/step - loss: 1.1676 - root_mean_squared_error: 1.0790 - val_loss: 1.0215 - val_root_mean_squared_error: 0.9908
#
# Epoch 00007: val_root_mean_squared_error did not improve from 0.98895
# Epoch 8/25
# 14832969/14832969 [==============================] - 129s 9us/step - loss: 1.1493 - root_mean_squared_error: 1.0705 - val_loss: 0.9911 - val_root_mean_squared_error: 0.9732
#
# Epoch 00008: val_root_mean_squared_error improved from 0.98895 to 0.97321, saving model to model_2.hdf5
# Epoch 9/25
# 14832969/14832969 [==============================] - 129s 9us/step - loss: 1.1341 - root_mean_squared_error: 1.0633 - val_loss: 0.9981 - val_root_mean_squared_error: 0.9781
#
# Epoch 00009: val_root_mean_squared_error did not improve from 0.97321
# Epoch 10/25
# 14832969/14832969 [==============================] - 129s 9us/step - loss: 1.1254 - root_mean_squared_error: 1.0592 - val_loss: 0.9940 - val_root_mean_squared_error: 0.9749
#
# Epoch 00010: val_root_mean_squared_error did not improve from 0.97321
# Epoch 11/25
# 14832969/14832969 [==============================] - 127s 9us/step - loss: 1.1169 - root_mean_squared_error: 1.0552 - val_loss: 0.9777 - val_root_mean_squared_error: 0.9662
#
# Epoch 00011: val_root_mean_squared_error improved from 0.97321 to 0.96621, saving model to model_2.hdf5
# Epoch 12/25
# 14832969/14832969 [==============================] - 128s 9us/step - loss: 1.1084 - root_mean_squared_error: 1.0512 - val_loss: 0.9881 - val_root_mean_squared_error: 0.9709
#
# Epoch 00012: val_root_mean_squared_error did not improve from 0.96621
# Epoch 13/25
# 14832969/14832969 [==============================] - 128s 9us/step - loss: 1.1039 - root_mean_squared_error: 1.0491 - val_loss: 0.9693 - val_root_mean_squared_error: 0.9612
#
# Epoch 00013: val_root_mean_squared_error improved from 0.96621 to 0.96123, saving model to model_2.hdf5
# Epoch 14/25
# 14832969/14832969 [==============================] - 128s 9us/step - loss: 1.1010 - root_mean_squared_error: 1.0477 - val_loss: 0.9799 - val_root_mean_squared_error: 0.9700
#
# Epoch 00014: val_root_mean_squared_error did not improve from 0.96123
# Epoch 15/25
# 14832969/14832969 [==============================] - 128s 9us/step - loss: 1.0976 - root_mean_squared_error: 1.0461 - val_loss: 0.9848 - val_root_mean_squared_error: 0.9710
#
# Epoch 00015: val_root_mean_squared_error did not improve from 0.96123
# Epoch 16/25
# 14832969/14832969 [==============================] - 128s 9us/step - loss: 1.0952 - root_mean_squared_error: 1.0449 - val_loss: 0.9781 - val_root_mean_squared_error: 0.9651
#
# Epoch 00016: val_root_mean_squared_error did not improve from 0.96123
# Epoch 00016: early stopping
# **************************************************
# Fold: 3
# Train on 14833419 samples, validate on 4943626 samples
# Epoch 1/25
# 14833419/14833419 [==============================] - 129s 9us/step - loss: 1.9077 - root_mean_squared_error: 1.3631 - val_loss: 1.4756 - val_root_mean_squared_error: 1.2014
#
# Epoch 00001: val_root_mean_squared_error improved from inf to 1.20144, saving model to model_3.hdf5
# Epoch 2/25
# 14833419/14833419 [==============================] - 131s 9us/step - loss: 1.4652 - root_mean_squared_error: 1.2087 - val_loss: 1.1607 - val_root_mean_squared_error: 1.0633
#
# Epoch 00002: val_root_mean_squared_error improved from 1.20144 to 1.06329, saving model to model_3.hdf5
# Epoch 3/25
# 14833419/14833419 [==============================] - 131s 9us/step - loss: 1.3133 - root_mean_squared_error: 1.1446 - val_loss: 1.0867 - val_root_mean_squared_error: 1.0226
#
# Epoch 00003: val_root_mean_squared_error improved from 1.06329 to 1.02262, saving model to model_3.hdf5
# Epoch 4/25
# 14833419/14833419 [==============================] - 131s 9us/step - loss: 1.2634 - root_mean_squared_error: 1.1225 - val_loss: 1.0463 - val_root_mean_squared_error: 1.0054
#
# Epoch 00004: val_root_mean_squared_error improved from 1.02262 to 1.00539, saving model to model_3.hdf5
# Epoch 5/25
# 14833419/14833419 [==============================] - 131s 9us/step - loss: 1.2322 - root_mean_squared_error: 1.1086 - val_loss: 1.0670 - val_root_mean_squared_error: 1.0159
#
# Epoch 00005: val_root_mean_squared_error did not improve from 1.00539
# Epoch 6/25
# 14833419/14833419 [==============================] - 132s 9us/step - loss: 1.2113 - root_mean_squared_error: 1.0991 - val_loss: 1.0244 - val_root_mean_squared_error: 0.9936
#
# Epoch 00006: val_root_mean_squared_error improved from 1.00539 to 0.99360, saving model to model_3.hdf5
# Epoch 7/25
# 14833419/14833419 [==============================] - 132s 9us/step - loss: 1.1967 - root_mean_squared_error: 1.0924 - val_loss: 1.0557 - val_root_mean_squared_error: 1.0107
#
# Epoch 00007: val_root_mean_squared_error did not improve from 0.99360
# Epoch 8/25
# 14833419/14833419 [==============================] - 132s 9us/step - loss: 1.1858 - root_mean_squared_error: 1.0875 - val_loss: 1.0302 - val_root_mean_squared_error: 0.9977
#
# Epoch 00008: val_root_mean_squared_error did not improve from 0.99360
# Epoch 9/25
# 14833419/14833419 [==============================] - 130s 9us/step - loss: 1.1728 - root_mean_squared_error: 1.0814 - val_loss: 1.0251 - val_root_mean_squared_error: 0.9938
#
# Epoch 00009: val_root_mean_squared_error did not improve from 0.99360
# Epoch 00009: early stopping
# **************************************************

# %%
# Test Data

# %%
building_df = pd.read_csv("/Users/x/Downloads/NN/building_metadata.csv")
test = pd.read_csv("/Users/x/Downloads/NN/test.csv")

test = test.merge(building_df, left_on = "building_id", right_on = "building_id", how = "left")
del building_df
gc.collect()
test["primary_use"] = le.transform(test["primary_use"])

weather_test = pd.read_csv("/Users/x/Downloads/NN/weather_test.csv")

test = test.merge(weather_test, left_on = ["site_id", "timestamp"], right_on = ["site_id", "timestamp"], how = "left")
del weather_test

# %%
test["timestamp"] = pd.to_datetime(test["timestamp"])
test["hour"] = test["timestamp"].dt.hour
test["weekday"] = test["timestamp"].dt.weekday

test = average_imputation(test, 'wind_speed')

for item in beaufort:
    test.loc[(test['wind_speed']>=item[1]) & (test['wind_speed']<item[2]), 'beaufort_scale'] = item[0]

    
test = test[feat_cols]
test, NAlist = reduce_mem_usage(test)
# Out:
# Memory usage of properties dataframe is : 6051.91162109375  MB
# ******************************
# Column:  site_id
# dtype before:  int64
# min for this col:  0
# max for this col:  15
# dtype after:  uint8
# ******************************
# ******************************
# Column:  building_id
# dtype before:  int64
# min for this col:  0
# max for this col:  1448
# dtype after:  uint16
# ******************************
# ******************************
# Column:  primary_use
# dtype before:  int64
# min for this col:  0
# max for this col:  15
# dtype after:  uint8
# ******************************
# ******************************
# Column:  hour
# dtype before:  int64
# min for this col:  0
# max for this col:  23
# dtype after:  uint8
# ******************************
# ******************************
# Column:  weekday
# dtype before:  int64
# min for this col:  0
# max for this col:  6
# dtype after:  uint8
# ******************************
# ******************************
# Column:  meter
# dtype before:  int64
# min for this col:  0
# max for this col:  3
# dtype after:  uint8
# ******************************
# ******************************
# Column:  square_feet
# dtype before:  int64
# min for this col:  283
# max for this col:  875000
# dtype after:  uint32
# ******************************
# ******************************
# Column:  year_built
# dtype before:  float64
# min for this col:  1900.0
# max for this col:  2017.0
# dtype after:  uint16
# ******************************
# ******************************
# Column:  air_temperature
# dtype before:  float64
# min for this col:  -28.1
# max for this col:  48.3
# dtype after:  float32
# ******************************
# ******************************
# Column:  cloud_coverage
# dtype before:  float64
# min for this col:  0.0
# max for this col:  9.0
# dtype after:  uint8
# ******************************
# ******************************
# Column:  dew_temperature
# dtype before:  float64
# min for this col:  -31.6
# max for this col:  26.7
# dtype after:  float32
# ******************************
# ******************************
# Column:  precip_depth_1_hr
# dtype before:  float64
# min for this col:  -1.0
# max for this col:  597.0
# dtype after:  int16
# ******************************
# ******************************
# Column:  floor_count
# dtype before:  float64
# min for this col:  1.0
# max for this col:  26.0
# dtype after:  uint8
# ******************************
# ******************************
# Column:  beaufort_scale
# dtype before:  float64
# min for this col:  0.0
# max for this col:  9.0
# dtype after:  uint8
# ******************************
# ___MEMORY USAGE AFTER COMPLETION:___
# Memory usage is:  2632.0416259765625  MB
# This is  43.491078369397584 % of the initial size

# %%
from tqdm import tqdm
i=0
res = np.zeros((test.shape[0]),dtype=np.float32)
step_size = 50000
for j in tqdm(range(int(np.ceil(test.shape[0]/step_size)))):
    for_prediction = get_keras_data(test.iloc[i:i+step_size], numericals, categoricals)
    res[i:min(i+step_size,test.shape[0])] = \
       np.expm1(sum([model.predict(for_prediction, batch_size=1024)[:,0] for model in models])/folds)
    i+=step_size
# Out:
# 100%|██████████| 834/834 [07:38<00:00,  1.82it/s]

# %%
submission = pd.read_csv('/Users/x/Downloads/NN/sample_submission.csv')
submission['meter_reading'] = res
submission.loc[submission['meter_reading']<0, 'meter_reading'] = 0
submission.to_csv('my_submission1.csv', index=False)
submission
# Out:
#             row_id  meter_reading
# 0                0     163.075470
# 1                1      83.058968
# 2                2      12.625435
# 3                3     227.250290
# 4                4     869.515381
# ...            ...            ...
# 41697595  41697595      11.543445
# 41697596  41697596       5.334345
# 41697597  41697597       6.671353
# 41697598  41697598     217.000763
# 41697599  41697599       3.533469
#
# [41697600 rows x 2 columns]
